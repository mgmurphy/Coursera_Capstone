# %% [markdown]
# This notebook will be mainly used for the Coursera Capstone project. Owner - Martin Murphy

# %%
import pandas as pd

# %%
import numpy as np

# %%
print("Hello Capstone Project Course")
# Out:
# Hello Capstone Project Course
